# %%
from pymongo import MongoClient, DESCENDING
import json
import networkx as nx
from collections import defaultdict, deque

SECRETS = {
  "MONGO_HOST": "immuno5.dfci.harvard.edu",
  "MONGO_PORT": 27019,
  "MONGO_DBNAME": "matchminer",
  "MONGO_AUTH_SOURCE": "admin",
  "MONGO_RO_USERNAME": "mmReadOnlyUser",
  "MONGO_RO_PASSWORD": "awifbv4ouwnvkjsdbff"
}
    
    

TARGET_DB = SECRETS["MONGO_DBNAME"]

class MongoDBConnection(object):
    uri = "mongodb://{username}:{password}@{hostname}:{port}/{db}?authSource=admin&replicaSet=rs0"
    read_only = None
    db = None
    client = None

    def __init__(self, read_only = True, db = TARGET_DB):
        self.read_only = read_only
        self.db = db

    def __enter__(self):
        self.client = MongoClient(
            self.uri.format(username=SECRETS["MONGO_RO_USERNAME"],
                            password=SECRETS["MONGO_RO_PASSWORD"],
                            hostname=SECRETS["MONGO_HOST"],
                            port=SECRETS["MONGO_PORT"],
                            db=self.db))
        return self.client[self.db]

    def __exit__(self, exc_type, exc_val, exc_tb):
        self.client.close()
        
with MongoDBConnection(read_only=True, db=TARGET_DB) as ro_target_db:
    trials = [result for result in ro_target_db.trial.find()]

to_process = dict()
for trial in trials:
    match_q = deque()
    process_q = deque()
    for k, v in trial.items():
        if k == 'match':
            match_q.append((list(), v))
        else:
            process_q.append((tuple(), k, v))
    while process_q:
        path, p_key, p_val = process_q.pop()
        if isinstance(p_val, dict):
            for i_k, i_v in p_val.items():
                if i_k == 'match':
                    match_q.append((path + (p_key, i_k), i_v))
                else:
                    process_q.append((path + (p_key,), i_k, i_v))
        elif isinstance(p_val, list):
            for idx, item in enumerate(p_val):
                process_q.append((path + (p_key,), idx, item))
                
    to_process[trial['protocol_no']] = match_q

# import pickle
# with open('to_proccess.pkl1', 'wb') as f:
#     pickle.dump(to_process, f)

# import pickle
# with open('to_proccess.pkl', 'rb') as f:
#     to_process = pickle.load(f)

def gen(match):
    process_q = deque()
    g = nx.DiGraph()
    counter = 1
#     for item in match:
#         g.add_edges_from([(0, counter)])
#         g.nodes[0]['list'] = list()
#         g.nodes[counter]['list'] = list()
#         process_q.append((counter, item))
#         counter += 1
    g.add_node(0)
    g.nodes[0]['list'] = list()
    for item in match:
            process_q.append((0, item))
    while process_q:
        parent, values = process_q.pop()
        parent_is_or = True if g.nodes[parent].setdefault('is_or', False) else False
        for label, value in values.items():
            if label == 'and':
                for item in value:
                    process_q.append((parent, item))
            elif label == "or":
                g.add_edges_from([(parent, counter)])
                g.nodes[counter]['list'] = list()
                g.nodes[counter]['is_or'] = True
                for item in value:
                    process_q.append((counter, item))
                counter += 1
            elif parent_is_or:
                g.add_edges_from([(parent, counter)])
                g.nodes[counter]['list'] = [values]
                counter += 1
            else:
                g.nodes[parent]['list'].append({label: value})
    return g

import networkx as nx
from networkx.drawing import spring_layout, bipartite_layout
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt
# %matplotlib inline
queries = defaultdict(list)
graphs = defaultdict(list)
count = 0
from time import sleep
for protocol_no, match_q in to_process.items():
    if protocol_no != '16-750':
        pass
        #         continue
    while match_q:
        match_path, match_clause = match_q.pop()
        g = gen(match_clause)
        graphs[protocol_no].append(g)
        root = 0
        leaves = [node for node in g.nodes if g.in_degree(node) and not g.out_degree(node)] if len(g.nodes) > 1 else g.nodes
        match_queries = list()
        for leaf in leaves:
            for path in nx.all_simple_paths(g, root, leaf):
                query = list()
                for node in path:
                    query.extend(g.nodes[node]['list'])
                match_queries.append(query)
                queries[protocol_no].append(queries)
                count += 1
        print(str((protocol_no, match_path, len(match_queries))))
        pos = graphviz_layout(g, prog="dot", root=0)
        size = [len(g.nodes[node]['list']) for node in g.nodes]
        norm = [200 + 1000*(float(i)/sum(size)) for i in size]
        plt.figure(figsize=(10,10))
        nx.draw_networkx(g, pos, with_labels=True, node_size=norm)
        plt.show()
# Out:
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 6, 'match'), 0)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 7, 'match'), 0)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 10, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 11, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 12, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 13, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 14, 'match'), 0)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 15, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 16, 'match'), 0)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 17, 'match'), 2)
# ('11-010', ('treatment_list', 'step', 0, 'arm', 0, 'dose_level', 18, 'match'), 2)
# ...
